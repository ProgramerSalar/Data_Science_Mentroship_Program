# %%
import pandas as pd 
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ca26d80b847990f9bbc704815503a73d&language=en-US&page=1')
response
# Out:
# <Response [200]>

# %%
temp_df = pd.DataFrame(response.json()['results'])[["id", "title", "overview", "release_date", "popularity", "vote_average", "vote_count"]]
temp_df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6    19404                    Dilwale Dulhania Le Jayenge
# 7      155                                The Dark Knight
# 8   496243                                       Parasite
# 9      497                                 The Green Mile
# 10  372058                                     Your Name.
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# ...

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dataframes = []
for i in range(1, 429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ca26d80b847990f9bbc704815503a73d&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[["id", "title", "overview", "release_date", "popularity", "vote_average", "vote_count"]]
    dataframes.append(temp_df)
df = pd.concat(dataframes, ignore_index=True)

# %%
df.sample()
# Out:
#           id           title  \
# 3974  449443  Den of Thieves
#
#                                                overview release_date  \
# 3974  A gritty crime saga which follows the lives of...   2018-01-18
#
#       popularity  vote_average  vote_count
# 3974      56.885         6.803        2719

# %% [markdown]
# # DataFrame convert to csv

# %%
df.to_csv('movies_csv')

# %% [markdown]
# Rapid API= https://rapidapi.com/hub
